# %%
# Import the research library 
import logging
import benchmarklib
from benchmarklib import BenchmarkDatabase, CompileType, GroverRunner, GroverConfig, calculate_grover_iterations

benchmarklib.setup_logging(logging.INFO)

from sat import ThreeSat, ThreeSatTrial

db = BenchmarkDatabase("3SAT.db", ThreeSat, ThreeSatTrial)
# Out:
# benchmarklib.quantum_trials - INFO - Database initialized: 3SAT.db (3SAT)

# %%
# Load Qiskit
from qiskit_ibm_runtime import QiskitRuntimeService, Batch
from dotenv import load_dotenv, find_dotenv
import os

load_dotenv()
API_TOKEN = os.getenv("API_TOKEN")
API_INSTANCE = os.getenv("API_INSTANCE", None)
service = QiskitRuntimeService(channel="ibm_cloud", token=API_TOKEN, instance=API_INSTANCE)
backend = service.backend(name="ibm_rensselaer")

# %%
# Configure Grover Benchmark
config = GroverConfig(shots=10**4, optimization_level=3)
runner = GroverRunner(db_manager=db, service=service, backend=backend, config=config)
# Out:
# benchmarklib.grover - INFO - GroverRunner initialized for 3SAT problems

# %%
# problem parameters
num_vars_range = range(9, 11)

# %%
for compile_type in [CompileType.CLASSICAL_FUNCTION, CompileType.XAG]:
    runner.start_batch(compile_type)
    
    for num_vars in num_vars_range:
        # Accumulate circuits for this num_vars group
        for problem in db.find_problem_instances(size_filters={'num_vars': num_vars}, ...):
            optimal_grover_iters = calculate_grover_iterations(len(problem.solutions), 2**num_vars)
            for grover_iter in range(1, optimal_grover_iters + 1):
                runner.run_grover_benchmark(
                    problem_instance=problem,
                    compile_type=compile_type, 
                    grover_iterations=grover_iter,
                )
        
        # Submit all circuits for this num_vars as one job
        job_id = runner.submit_job()
        print(f"Submitted job {job_id} for {compile_type.value}, {num_vars} vars")
    
    runner.finish_batch()
# Out:
# benchmarklib.grover - INFO - Problem Instance ID: 1478
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:05:35,926: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d18d3grvg008j7gv0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3852
# benchmarklib.grover - INFO - Problem Instance ID: 1478
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:05:52,180: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d1c55z6q00087h5mg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3853
# benchmarklib.grover - INFO - Problem Instance ID: 1868
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:06:12,923: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d1hpv3z500082twqg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3854
# benchmarklib.grover - INFO - Problem Instance ID: 1868
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:06:27,333: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d1n63grvg008j7h00 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3855
# benchmarklib.grover - INFO - Problem Instance ID: 1548
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:06:54,190: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d1vq3grvg008j7h20 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3856
# benchmarklib.grover - INFO - Problem Instance ID: 1548
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:07:12,775: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d20g5z6q00087h5w0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3857
# benchmarklib.grover - INFO - Problem Instance ID: 1540
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:07:34,523: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d25r3grvg008j7h40 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3858
# benchmarklib.grover - INFO - Problem Instance ID: 1540
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:07:53,815: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d2ahqf56g0081ysn0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3859
# benchmarklib.grover - INFO - Problem Instance ID: 1540
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:08:12,823: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d2f9mya70008espw0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3860
# benchmarklib.grover - INFO - Problem Instance ID: 1540
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:08:31,227: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d2ktv3z500082tx1g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3861
# benchmarklib.grover - INFO - Problem Instance ID: 2000
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:08:51,496: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d2s3n2txg008k0k5g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3862
# benchmarklib.grover - INFO - Problem Instance ID: 2000
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:09:11,644: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d2y3mya70008espz0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3863
# benchmarklib.grover - INFO - Problem Instance ID: 1683
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:09:36,201: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d344mya70008esq3g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3864
# benchmarklib.grover - INFO - Problem Instance ID: 1683
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (40) in circuit-447845 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:10:00,237: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d3adqf56g0081yst0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3865
# benchmarklib.grover - INFO - Problem Instance ID: 1676
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:10:27,235: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d3gyn2txg008k0kbg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3866
# benchmarklib.grover - INFO - Problem Instance ID: 1676
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:10:51,387: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d3pyv3z500082txa0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3867
# benchmarklib.grover - INFO - Problem Instance ID: 1676
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:11:14,021: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d3wzv3z500082txb0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3868
# benchmarklib.grover - INFO - Problem Instance ID: 1676
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (46) in circuit-448390 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:11:56,833: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d4785z6q00087h68g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3869
# benchmarklib.grover - INFO - Problem Instance ID: 1676
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (46) in circuit-448616 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:12:47,079: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d4m25z6q00087h6ag to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3870
# benchmarklib.grover - INFO - Problem Instance ID: 1676
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (46) in circuit-448902 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:13:31,853: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d4zbmya70008esqh0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3871
# benchmarklib.grover - INFO - Problem Instance ID: 1656
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:14:17,524: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d5an5z6q00087h6j0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3872
# benchmarklib.grover - INFO - Problem Instance ID: 1656
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:15:00,506: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d5ne5z6q00087h6kg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3873
# benchmarklib.grover - INFO - Problem Instance ID: 1656
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:15:43,298: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d6083grvg008j7hz0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3874
# benchmarklib.grover - INFO - Problem Instance ID: 1656
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:16:26,007: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d6ah5z6q00087h6r0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3875
# benchmarklib.grover - INFO - Problem Instance ID: 1956
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:17:12,438: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d6pa5z6q00087h6t0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3876
# benchmarklib.grover - INFO - Problem Instance ID: 1956
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:17:47,398: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d6z33grvg008j7j20 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3877
# benchmarklib.grover - INFO - Problem Instance ID: 1956
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:18:20,790: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d77cv3z500082txqg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3878
# benchmarklib.grover - INFO - Problem Instance ID: 1956
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:18:53,065: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d7fnqf56g0081ytkg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3879
# benchmarklib.grover - INFO - Problem Instance ID: 74
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:19:46,544: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d7wz3grvg008j7j9g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3880
# benchmarklib.grover - INFO - Problem Instance ID: 74
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (54) in circuit-449615 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:20:43,006: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d8b1qf56g0081ytsg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3881
# benchmarklib.grover - INFO - Problem Instance ID: 2051
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:21:19,915: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d8mav3z500082ty00 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3882
# benchmarklib.grover - INFO - Problem Instance ID: 2051
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:21:57,601: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d8xkqf56g0081ytyg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3883
# benchmarklib.grover - INFO - Problem Instance ID: 77
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:22:48,682: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d9adqf56g0081yv00 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3884
# benchmarklib.grover - INFO - Problem Instance ID: 77
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:23:42,374: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15d9qy5z6q00087h7a0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3885
# benchmarklib.grover - INFO - Problem Instance ID: 77
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (49) in circuit-450770 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:24:40,985: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15da68n2txg008k0mk0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3886
# benchmarklib.grover - INFO - Problem Instance ID: 77
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (49) in circuit-451006 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:25:33,606: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dakjv3z500082tyc0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3887
# benchmarklib.grover - INFO - Problem Instance ID: 2010
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:26:16,868: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15daykmya70008esrd0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3888
# benchmarklib.grover - INFO - Problem Instance ID: 2010
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:26:56,208: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15db85n2txg008k0mrg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3889
# benchmarklib.grover - INFO - Problem Instance ID: 2008
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:27:36,931: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dbjp3grvg008j7jx0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3890
# benchmarklib.grover - INFO - Problem Instance ID: 2008
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:28:19,990: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dbxfn2txg008k0mvg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3891
# benchmarklib.grover - INFO - Problem Instance ID: 2011
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:29:02,747: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dc7rmya70008esrj0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3892
# benchmarklib.grover - INFO - Problem Instance ID: 2011
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (41) in circuit-451976 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:29:47,444: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dck2n2txg008k0mzg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3893
# benchmarklib.grover - INFO - Problem Instance ID: 23
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:30:43,577: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dd14n2txg008k0n4g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3894
# benchmarklib.grover - INFO - Problem Instance ID: 23
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:31:38,467: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15ddexqf56g0081yvwg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3895
# benchmarklib.grover - INFO - Problem Instance ID: 23
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (53) in circuit-452863 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:32:31,607: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15ddw73grvg008j7kag to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3896
# benchmarklib.grover - INFO - Problem Instance ID: 23
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (53) in circuit-453125 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:33:27,390: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dea9mya70008ess60 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3897
# benchmarklib.grover - INFO - Problem Instance ID: 57
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:34:20,236: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15deqaqf56g0081yw5g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3898
# benchmarklib.grover - INFO - Problem Instance ID: 57
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:35:13,571: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15df4m5z6q00087h83g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3899
# benchmarklib.grover - INFO - Problem Instance ID: 57
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (51) in circuit-453909 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:36:10,867: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dfk6mya70008esseg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3900
# benchmarklib.grover - INFO - Problem Instance ID: 57
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (51) in circuit-454156 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:36:46,795: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dfvzqf56g0081ywb0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3901
# benchmarklib.grover - INFO - Problem Instance ID: 2038
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:37:10,752: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dg1r5z6q00087h890 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3902
# benchmarklib.grover - INFO - Problem Instance ID: 2038
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (42) in circuit-454653 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:37:32,638: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dg785z6q00087h8a0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3903
# benchmarklib.grover - INFO - Problem Instance ID: 6
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:38:01,684: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dgeh5z6q00087h8bg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3904
# benchmarklib.grover - INFO - Problem Instance ID: 6
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (57) in circuit-455082 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:38:32,441: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dgpa3grvg008j7m0g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3905
# benchmarklib.grover - INFO - Problem Instance ID: 122
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:39:06,826: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dgyvn2txg008k0nyg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3906
# benchmarklib.grover - INFO - Problem Instance ID: 122
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:39:42,734: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dh7wqf56g0081ywk0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3907
# benchmarklib.grover - INFO - Problem Instance ID: 122
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:40:14,543: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dhg65z6q00087h8k0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3908
# benchmarklib.grover - INFO - Problem Instance ID: 122
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:40:50,806: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dhrzn2txg008k0p4g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3909
# benchmarklib.grover - INFO - Problem Instance ID: 122
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (64) in circuit-457474 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:41:25,128: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dj1gqf56g0081ywpg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3910
# benchmarklib.grover - INFO - Problem Instance ID: 122
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (64) in circuit-457778 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:42:08,718: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15djchn2txg008k0p70 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3911
# benchmarklib.grover - INFO - Problem Instance ID: 122
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (64) in circuit-458156 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:42:47,010: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15djp2qf56g0081ywv0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3912
# benchmarklib.grover - INFO - Problem Instance ID: 122
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (64) in circuit-458608 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:43:45,634: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dk4wv3z500082v010 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3913
# benchmarklib.grover - INFO - Problem Instance ID: 2174
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:44:10,458: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dkaxn2txg008k0pbg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3914
# benchmarklib.grover - INFO - Problem Instance ID: 2174
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (51) in circuit-459469 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:44:36,069: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dkh65z6q00087h8yg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3915
# benchmarklib.grover - INFO - Problem Instance ID: 113
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:45:09,776: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dkszmya70008est4g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3916
# benchmarklib.grover - INFO - Problem Instance ID: 113
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:45:48,533: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dm38mya70008est50 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3917
# benchmarklib.grover - INFO - Problem Instance ID: 113
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (69) in circuit-459991 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:46:27,366: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dmd1qf56g0081ywz0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3918
# benchmarklib.grover - INFO - Problem Instance ID: 113
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (69) in circuit-460341 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:47:05,263: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dmpjv3z500082v09g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3919
# benchmarklib.grover - INFO - Problem Instance ID: 178
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:47:34,705: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dmy3v3z500082v0a0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3920
# benchmarklib.grover - INFO - Problem Instance ID: 178
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:48:12,945: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dn7m3grvg008j7mqg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3921
# benchmarklib.grover - INFO - Problem Instance ID: 178
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (66) in circuit-461606 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:48:47,893: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dng6mya70008estb0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3922
# benchmarklib.grover - INFO - Problem Instance ID: 178
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (66) in circuit-461932 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:49:19,308: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dnr7qf56g0081yx20 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3923
# benchmarklib.grover - INFO - Problem Instance ID: 2109
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:49:54,751: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dp105z6q00087h98g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3924
# benchmarklib.grover - INFO - Problem Instance ID: 2109
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:50:23,161: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dp7r3grvg008j7mvg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3925
# benchmarklib.grover - INFO - Problem Instance ID: 2109
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (53) in circuit-463271 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:50:54,362: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dpfsmya70008estfg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3926
# benchmarklib.grover - INFO - Problem Instance ID: 2109
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (53) in circuit-463523 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:51:18,643: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dpntv3z500082v0k0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3927
# benchmarklib.grover - INFO - Problem Instance ID: 2166
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:51:47,332: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dpx3qf56g0081yx6g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3928
# benchmarklib.grover - INFO - Problem Instance ID: 2166
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (47) in circuit-464184 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:52:17,851: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dq4wn2txg008k0pw0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3929
# benchmarklib.grover - INFO - Problem Instance ID: 142
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:52:58,041: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dqenn2txg008k0pwg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3930
# benchmarklib.grover - INFO - Problem Instance ID: 142
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:53:40,519: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dqsfqf56g0081yx9g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3931
# benchmarklib.grover - INFO - Problem Instance ID: 142
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (70) in circuit-465520 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:54:19,773: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dr38n2txg008k0py0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3932
# benchmarklib.grover - INFO - Problem Instance ID: 142
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (70) in circuit-465868 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:54:51,371: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15drb15z6q00087h9dg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3933
# benchmarklib.grover - INFO - Problem Instance ID: 2113
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:55:20,033: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15drj2n2txg008k0pyg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3934
# benchmarklib.grover - INFO - Problem Instance ID: 2113
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (57) in circuit-466563 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:55:45,252: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15drrbn2txg008k0pz0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3935
# benchmarklib.grover - INFO - Problem Instance ID: 2153
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:56:10,354: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dryvmya70008estr0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3936
# benchmarklib.grover - INFO - Problem Instance ID: 2153
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:56:35,361: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15ds54n2txg008k0q1g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3937
# benchmarklib.grover - INFO - Problem Instance ID: 2153
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:57:00,667: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dsbn3grvg008j7n5g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3938
# benchmarklib.grover - INFO - Problem Instance ID: 2153
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (50) in circuit-468450 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:57:31,267: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dsk6qf56g0081yxg0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3939
# benchmarklib.grover - INFO - Problem Instance ID: 2153
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (50) in circuit-468684 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:57:56,911: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dssfqf56g0081yxgg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3940
# benchmarklib.grover - INFO - Problem Instance ID: 2153
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (50) in circuit-468978 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:58:25,847: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dt0gn2txg008k0q40 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3941
# benchmarklib.grover - INFO - Problem Instance ID: 2269
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:59:01,269: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dt9hv3z500082v0wg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3942
# benchmarklib.grover - INFO - Problem Instance ID: 2269
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (63) in circuit-470956 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 09:59:31,705: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dth23grvg008j7n90 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3943
# benchmarklib.grover - INFO - Problem Instance ID: 2281
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:00:02,380: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dtrvqf56g0081yxmg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3944
# benchmarklib.grover - INFO - Problem Instance ID: 2281
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:00:38,634: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dv24qf56g0081yxn0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3945
# benchmarklib.grover - INFO - Problem Instance ID: 2281
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (60) in circuit-473519 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:01:05,667: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dv8nmya70008esv2g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3946
# benchmarklib.grover - INFO - Problem Instance ID: 2281
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (60) in circuit-473801 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:01:34,796: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dvfxv3z500082v13g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3947
# benchmarklib.grover - INFO - Problem Instance ID: 2202
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:02:05,855: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dvqyqf56g0081yxrg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3948
# benchmarklib.grover - INFO - Problem Instance ID: 2202
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:02:40,623: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dw0gqf56g0081yxtg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3949
# benchmarklib.grover - INFO - Problem Instance ID: 2202
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:03:12,749: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dw8h3grvg008j7neg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3950
# benchmarklib.grover - INFO - Problem Instance ID: 2202
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (62) in circuit-476578 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:03:38,142: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dwesqf56g0081yxwg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3951
# benchmarklib.grover - INFO - Problem Instance ID: 2202
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (62) in circuit-476878 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:04:08,809: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dwpaqf56g0081yxy0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3952
# benchmarklib.grover - INFO - Problem Instance ID: 2202
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (62) in circuit-477260 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:04:40,735: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dwykmya70008esv80 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3953
# benchmarklib.grover - INFO - Problem Instance ID: 2297
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:05:12,249: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dx645z6q00087ha0g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3954
# benchmarklib.grover - INFO - Problem Instance ID: 2297
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:05:42,952: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dxdxv3z500082v16g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3955
# benchmarklib.grover - INFO - Problem Instance ID: 2297
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:06:06,477: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dxky5z6q00087ha20 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3956
# benchmarklib.grover - INFO - Problem Instance ID: 2297
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 10:06:34,066: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15dxtz3grvg008j7nng to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 3957
# benchmarklib.grover - INFO - Problem Instance ID: 2297
# ...
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 11:55:03,482: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fgpj5z6q00087hh50 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4096
# benchmarklib.grover - INFO - Problem Instance ID: 450
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (110) in circuit-625759 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 11:56:13,030: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fh7wmya70008et2fg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4097
# benchmarklib.grover - INFO - Problem Instance ID: 424
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 11:57:01,610: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fhkymya70008et2n0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4098
# benchmarklib.grover - INFO - Problem Instance ID: 424
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 11:58:01,922: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fj2rmya70008et2q0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4099
# benchmarklib.grover - INFO - Problem Instance ID: 424
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 11:59:03,534: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fjjj5z6q00087hhg0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4100
# benchmarklib.grover - INFO - Problem Instance ID: 424
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:00:16,591: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fk4wmya70008et2tg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4101
# benchmarklib.grover - INFO - Problem Instance ID: 424
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-633865 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:01:01,220: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fkfxqf56g0081z4rg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4102
# benchmarklib.grover - INFO - Problem Instance ID: 424
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-634375 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:02:02,283: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fkz7v3z500082v7w0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4103
# benchmarklib.grover - INFO - Problem Instance ID: 424
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-635017 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:02:57,833: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fmd1v3z500082v81g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4104
# benchmarklib.grover - INFO - Problem Instance ID: 424
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-635791 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:03:53,960: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fmvb5z6q00087hhx0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4105
# benchmarklib.grover - INFO - Problem Instance ID: 439
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:04:41,046: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fn6w3grvg008j7x9g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4106
# benchmarklib.grover - INFO - Problem Instance ID: 439
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:05:30,101: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fnjyn2txg008k0z6g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4107
# benchmarklib.grover - INFO - Problem Instance ID: 439
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:06:35,097: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fp305z6q00087hj7g to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4108
# benchmarklib.grover - INFO - Problem Instance ID: 439
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:07:31,768: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fphjv3z500082v8ag to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4109
# benchmarklib.grover - INFO - Problem Instance ID: 439
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-641831 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:08:15,885: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fpwb3grvg008j7xng to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4110
# benchmarklib.grover - INFO - Problem Instance ID: 439
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-642373 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:09:15,618: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fqb53grvg008j7xsg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4111
# benchmarklib.grover - INFO - Problem Instance ID: 439
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-643063 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:10:13,531: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fqt7mya70008et3tg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4112
# benchmarklib.grover - INFO - Problem Instance ID: 439
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-643901 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:11:14,692: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fr9hn2txg008k0ztg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4113
# benchmarklib.grover - INFO - Problem Instance ID: 464
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:12:05,824: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15frntmya70008et470 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4114
# benchmarklib.grover - INFO - Problem Instance ID: 464
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:13:09,252: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fs5w5z6q00087hke0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4115
# benchmarklib.grover - INFO - Problem Instance ID: 464
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:14:09,079: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fsmy5z6q00087hm00 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4116
# benchmarklib.grover - INFO - Problem Instance ID: 464
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:15:27,749: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15ft8hqf56g0081z810 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4117
# benchmarklib.grover - INFO - Problem Instance ID: 464
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-653675 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:16:20,095: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15ftnav3z500082vav0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4118
# benchmarklib.grover - INFO - Problem Instance ID: 464
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-654213 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:17:06,210: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fv143grvg008j8020 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4119
# benchmarklib.grover - INFO - Problem Instance ID: 464
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-654895 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:18:05,693: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fvfx3grvg008j8090 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4120
# benchmarklib.grover - INFO - Problem Instance ID: 464
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (108) in circuit-655721 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:19:05,680: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fvz7mya70008et6s0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4121
# benchmarklib.grover - INFO - Problem Instance ID: 492
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:19:58,594: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fwchn2txg008k12fg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4122
# benchmarklib.grover - INFO - Problem Instance ID: 492
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:21:25,466: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fx24qf56g0081z8z0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4123
# benchmarklib.grover - INFO - Problem Instance ID: 492
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:23:09,577: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fxwf5z6q00087hnb0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4124
# benchmarklib.grover - INFO - Problem Instance ID: 492
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:25:00,883: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fys3qf56g0081z9n0 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4125
# benchmarklib.grover - INFO - Problem Instance ID: 492
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-677693 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:25:57,719: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fz5wv3z500082vc60 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4126
# benchmarklib.grover - INFO - Problem Instance ID: 492
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-678225 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:26:52,004: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15fzke3grvg008j81gg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4127
# benchmarklib.grover - INFO - Problem Instance ID: 492
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-678911 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:28:01,940: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15g0505z6q00087hp00 to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4128
# benchmarklib.grover - INFO - Problem Instance ID: 492
# benchmarklib.grover - ERROR - Simulation failed: 'Number of qubits (104) in circuit-679751 is greater than maximum (30) in the coupling_map'
# base_primitive._get_mode_service_backend:WARNING:2025-06-12 12:29:01,671: A backend was passed in as the mode but a session context manager is open so this job will run inside this session/batch instead of in job mode.
# benchmarklib.grover - INFO - Submitted job d15g0m2v3z500082vcmg to ibm_rensselaer
# benchmarklib.grover - INFO - Saved trial 4129

# %%
"""
Simple Parallel Benchmark Driver

Strategy:
1. Sequential phase: Collect all work that needs to be done
2. Split work into chunks for each worker thread
3. Each thread processes its chunk independently with Batch context
"""

import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import List, Tuple
from qiskit_ibm_runtime import Batch

def collect_needed_trials(
    db: BenchmarkDatabase, 
    num_vars_range: range
) -> List[Tuple[ProblemInstance, CompileType, int]]:
    """
    Sequential phase: Collect all trials that need to be created.
    No concurrency here = no race conditions.
    
    Returns:
        List of (problem_instance, compile_type, grover_iterations) tuples
    """
    needed_trials = []
    
    print("Collecting trials that need to be created...")
    
    for num_vars in num_vars_range:
        print(f"  Checking {num_vars} variables...")
        
        problems = db.find_problem_instances(size_filters={'num_vars': num_vars})
        
        for problem in problems:
            optimal_grover_iters = calculate_grover_iterations(
                len(problem.solutions), 2**num_vars
            )
            
            for compile_type in [CompileType.CLASSICAL_FUNCTION, CompileType.XAG]:
                for grover_iter in range(1, optimal_grover_iters + 1):
                    
                    # Check if trial already exists
                    existing_trials = db.find_trials(
                        instance_id=problem.instance_id,
                        compile_type=compile_type,
                        trial_params={"grover_iterations": grover_iter},
                        include_pending=True,
                        limit=1  # Just need to know if any exist
                    )
                    
                    if not existing_trials:
                        needed_trials.append((problem, compile_type, grover_iter))
    
    print(f"Found {len(needed_trials)} trials that need to be created")
    return needed_trials

def process_trial_chunk(
    trial_chunk: List[Tuple[ProblemInstance, CompileType, int]],
    worker_id: int,
    db_name: str,
    problem_class,
    trial_class,
    service,
    backend
) -> int:
    """
    Worker function: Process a chunk of trials in a single thread.
    Each worker gets its own database connection and Grover runner.
    
    Args:
        trial_chunk: List of trials to process
        worker_id: Worker identification for logging
        db_name: Database filename
        problem_class: Problem class for database
        trial_class: Trial class for database  
        service: IBM Quantum service
        backend: IBM Quantum backend
        
    Returns:
        Number of trials successfully created
    """
    if not trial_chunk:
        return 0
    
    print(f"Worker {worker_id}: Processing {len(trial_chunk)} trials")
    
    # Create thread-local database and runner instances
    local_db = BenchmarkDatabase(db_name, problem_class, trial_class)
    local_runner = GroverRunner(local_db, service, backend)
    
    successful_trials = 0
    
    # Use Batch context for efficiency
    with Batch(backend) as batch:
        for i, (problem, compile_type, grover_iterations) in enumerate(trial_chunk):
            try:
                print(f"Worker {worker_id}: Trial {i+1}/{len(trial_chunk)} - "
                      f"Problem {problem.instance_id}, {compile_type.value}, "
                      f"{grover_iterations} iterations")
                
                trial = local_runner.run_grover_benchmark(
                    problem_instance=problem,
                    compile_type=compile_type,
                    grover_iterations=grover_iterations,
                    skip_existing=False,  # We already checked in sequential phase
                    save_to_db=True
                )
                
                successful_trials += 1
                
            except Exception as e:
                print(f"Worker {worker_id}: Failed to create trial - {e}")
                continue
    
    print(f"Worker {worker_id}: Successfully created {successful_trials} trials")
    return successful_trials

def split_list(items: List, num_chunks: int) -> List[List]:
    """Split list into roughly equal chunks."""
    chunk_size = len(items) // num_chunks
    remainder = len(items) % num_chunks
    
    chunks = []
    start = 0
    
    for i in range(num_chunks):
        # Add one extra item to first 'remainder' chunks
        current_chunk_size = chunk_size + (1 if i < remainder else 0)
        end = start + current_chunk_size
        
        if start < len(items):  # Only create chunk if there are items left
            chunks.append(items[start:end])
        
        start = end
    
    return [chunk for chunk in chunks if chunk]  # Remove empty chunks

def simple_parallel_benchmark(
    db: BenchmarkDatabase,
    num_vars_range: range,
    num_workers: int = 4
):
    """
    Simple parallel benchmark driver.
    
    Args:
        db: Database instance (only used for initial problem collection)
        num_vars_range: Range of variable counts to benchmark
        num_workers: Number of parallel worker threads
    """
    
    print(f"Starting simple parallel benchmark with {num_workers} workers")
    
    # Phase 1: Sequential collection (no race conditions)
    needed_trials = collect_needed_trials(db, num_vars_range)
    
    if not needed_trials:
        print("No trials need to be created!")
        return
    
    # Phase 2: Split work across workers
    trial_chunks = split_list(needed_trials, num_workers)
    
    print(f"Split {len(needed_trials)} trials into {len(trial_chunks)} chunks:")
    for i, chunk in enumerate(trial_chunks):
        print(f"  Worker {i}: {len(chunk)} trials")
    
    # Phase 3: Execute in parallel
    print("Starting parallel execution...")
    
    total_created = 0
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        # Submit all worker tasks
        future_to_worker = {
            executor.submit(
                process_trial_chunk,
                chunk,
                worker_id,
                db.db_name,          # Pass database filename
                db.problem_class,    # Pass class references
                db.trial_class,
                service,             # These need to be in scope
                backend
            ): worker_id
            for worker_id, chunk in enumerate(trial_chunks)
        }
        
        # Collect results as they complete
        for future in as_completed(future_to_worker):
            worker_id = future_to_worker[future]
            try:
                trials_created = future.result()
                total_created += trials_created
                print(f"Worker {worker_id} completed successfully")
            except Exception as e:
                print(f"Worker {worker_id} failed: {e}")
    
    print(f"Parallel benchmark completed: {total_created} trials created total")

# Even simpler version using basic threading
def simple_threaded_benchmark(
    db: BenchmarkDatabase,
    num_vars_range: range,
    num_workers: int = 4
):
    """
    Alternative using basic threading (no ThreadPoolExecutor)
    """
    
    # Phase 1: Collect work
    needed_trials = collect_needed_trials(db, num_vars_range)
    
    if not needed_trials:
        print("No trials need to be created!")
        return
    
    # Phase 2: Split work
    trial_chunks = split_list(needed_trials, num_workers)
    
    # Phase 3: Create and start threads
    threads = []
    results = {}
    
    def worker_wrapper(worker_id, chunk):
        """Wrapper to capture results"""
        try:
            result = process_trial_chunk(
                chunk, worker_id, db.db_name, db.problem_class, 
                db.trial_class, service, backend
            )
            results[worker_id] = result
        except Exception as e:
            print(f"Worker {worker_id} failed: {e}")
            results[worker_id] = 0
    
    # Start all workers
    for worker_id, chunk in enumerate(trial_chunks):
        thread = threading.Thread(
            target=worker_wrapper,
            args=(worker_id, chunk),
            name=f"BenchmarkWorker-{worker_id}"
        )
        thread.start()
        threads.append(thread)
    
    # Wait for completion
    for thread in threads:
        thread.join()
    
    # Report results
    total_created = sum(results.values())
    print(f"All workers completed: {total_created} trials created total")
    
    return total_created
