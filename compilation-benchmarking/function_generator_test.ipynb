# %%
from benchmark import get_oracle
from function_generator import get_random_statement, get_random_statement_old

# %%
statement, variables = get_random_statement(20, 15)
print(statement)
oracle = get_oracle(statement, variables)
oracle.draw()
# Out:
# not (not ((((((not (not ((((not (not ((x16) and (x9)))) ^ ((not ((x16) and (x9))) or (((x15) ^ (x17)) and (x2)))) and (x17)) or (not (x0))))) ^ (not (not (((((x16) and (x9)) or ((x7) and (x16))) and (x7)) and (x5))))) and ((((not ((not (not (((x15) ^ (x17)) and (x2)))) or (not (((not (x12)) ^ (x6)) and ((not (x16)) or ((x16) and (x6))))))) or (x18)) ^ ((x3) ^ (x18))) and ((not ((((not (x12)) or (x15)) and (x16)) or (x18))) or (not (x1))))) or (not ((((((x19) and (x11)) or ((x4) or (x2))) ^ (x11)) and (((x6) and (x17)) and ((x19) and (x11)))) or (x11)))) ^ (not (not ((x16) and (x9))))) and (not ((not ((x16) and (x9))) or (not ((x16) and (x9)))))))
#                                                                               »
#     x0: ──■────■────■────■────■────■────■────■────■────■────■──────────────■──»
#           │    │    │    │    │    │    │    │    │    │    │              │  »
#     x1: ──■────■────o────o────o────o────o────o────o────o────o──────────────o──»
# ...

# %%
statement, variables = get_random_statement_old(10, 6)
print(statement)
oracle = get_oracle(statement, variables)
oracle.draw()
# Out:
# ...
# ((((((x2) and (x2)) or (x1)) and (x2)) ^ (x0)) and (x6)) or ((x6) and ((x9) ^ ((x3) or (x8))))
#
#     x0: ──■──────────────■────■────────────
#           │              │    │
#     x1: ──┼──────────────┼────┼────────────
#           │              │    │
#     x2: ──┼────■────o────┼────┼─────────o──
#           │    │    │    │    │         │
#     x3: ──■────┼────┼────┼────┼─────────■──
#           │    │    │    │    │         │
#     x4: ──┼────┼────┼────┼────┼─────────┼──
#           │    │    │    │    │         │
#     x5: ──┼────┼────┼────┼────┼─────────┼──
#           │    │    │    │    │         │
#     x6: ──■────■────■────■────■────■────■──
#           │    │    │    │    │    │    │
#     x7: ──┼────┼────┼────┼────┼────┼────┼──
#           │    │    │    │    │    │    │
#     x8: ──o────┼────■────■────┼────┼────o──
#           │    │    │    │    │    │    │
#     x9: ──┼────o────┼────┼────o────■────┼──
#         ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐
# ...
